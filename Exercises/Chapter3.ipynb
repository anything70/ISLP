# %% [markdown]
# Conceptual

# %% [markdown]
# Question 1.
# There is a relationship/correlation between money spent on advertisements for the respective variables and the amount of units sold. A positive relationship will be the best. From the p-values, advertisements spent on TV and radio have a statistically significant relationship with units sold, in this case positive. Newspapers do not have a statistically significant relationship with units sold.
#
# Question 2.
# They take the same concept, using k points closest to an input value to predict a new value. KNN classification is in the context of classification, while KNN regression is in the context of regression.
#
# Question 3.
# a. Part (iii), because the interaction term between GPA and education level is negative, indicating that as GPA increases, the advantage of having a college degree decreases, leading high schoolers to have a higher salary with a sufficient GPA.
# c. This is false. The evidence of an interaction is dependent on the p-value, not the actual coefficient itself.
#
# Question 4.
# a. The residuals for the cubic regression would be lower. This is because since the actual line is linear, the cubic model would overfit to the training data.
# b. In context of testing data, the linear model should preform better. This is because the linear model would capture the true nature of the line of best fit, and the cubic model should not perform better on unseen data.
# c. Cubic relationships are more flexible and can capture relationships of data better on testing data.
# d. Unknown, we are not sure of how linear the line vs how cubic the line is.
#
# Question 5.
# ...
#
# Question 6.
# ...
#
# Question 7.
# ...

# %%
# Question 3b.
def salary(gpa, iq, level):
    y = 50+20*gpa+0.07*iq+35*level+0.01*(gpa*iq)-10*(gpa*level)
    print("Expected Salary:", y)
    return y
salary(4.0, 110, True)
# Out:
# Expected Salary: 137.1
# 137.1

# %% [markdown]
# APPLIED

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize,
                         poly)


df = load_data("auto")
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
#Question 8.
y = df["mpg"]
design = MS(["horsepower"])
X = design.fit_transform(df)
model = sm.OLS(y,X)
results = model.fit()
results.summary()

input = pd.DataFrame({"horsepower": [98]})
newX = design.fit_transform(input)
model =
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 6
#       4 X = design.fit_transform(df)
#       5 model = sm.OLS(y,X)
# ----> 6 model.summary()
#       8 input = pd.DataFrame({"horsepower": [98]})
#       9 newX = design.fit_transform(input)
#
# AttributeError: 'OLS' object has no attribute 'summary'

# %% [markdown]
# i. Yes. With a p value close to 0, it appears that there is a relationship between the two variables. (P-value)
# ii. It's a moderately strong relationship. (R-squared value)
# iii. The relationship between the predictor and response variable appears to be negative. (negative coefficient of horsepower)
